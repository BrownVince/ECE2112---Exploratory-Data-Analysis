# %%
#Import libraries needed for analyzing data
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the file that contains the data on Spotify playlist 2023
df = pd.read_csv('spotify2023.csv')

# %% [markdown]
# # Dataset Cleaning

# %%
#Converting streams column to a numerical column
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')

#Removing commas in in_deezer_playlists column then converting it to a numerical column
df['in_deezer_playlists'] = df['in_deezer_playlists'].str.replace(',', '')
df['in_deezer_playlists'] = pd.to_numeric(df['in_deezer_playlists'], errors='coerce')

#Removing commas in in_shazam_charts column then converting it to a numerical column
df['in_shazam_charts'] = df['in_shazam_charts'].str.replace(',', '')
df['in_shazam_charts'] = pd.to_numeric(df['in_shazam_charts'], errors='coerce')

df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# ..             ...             ...           ...                   ...
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts      streams  in_apple_playlists  ...  bpm  key   mode  \
# 0                  147  141381703.0                  43  ...  125    B  Major
# 1                   48  133716286.0                  48  ...   92   C#  Major
# 2                  113  140003974.0                  94  ...  138    F  Major
# 3                  100  800840817.0                 116  ...  170    A  Major
# 4                   50  303236322.0                  84  ...  144    A  Minor
# ..                 ...          ...                 ...  ...  ...  ...    ...
# 948                  0   91473363.0                  61  ...  144    A  Major
# 949                  0  121871870.0                   4  ...  166   F#  Major
# 950                  0   73513683.0                   2  ...   92   C#  Major
# 951                  0  133895612.0                  29  ...   97   C#  Major
# 952                  2   96007391.0                  27  ...   90    E  Minor
#
#      danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0                80         89       83             31                   0
# 1                71         61       74              7                   0
# 2                51         32       53             17                   0
# 3                55         58       72             11                   0
# 4                65         23       80             14                  63
# ..              ...        ...      ...            ...                 ...
# 948              60         24       39             57                   0
# 949              42          7       24             83                   1
# 950              80         81       67              4                   0
# 951              82         67       77              8                   0
# 952              61         32       67             15                   0
#
#      liveness_%  speechiness_%
# 0             8              4
# 1            10              4
# 2            31              6
# 3            11             15
# 4            11              6
# ..          ...            ...
# 948           8              3
# 949          12              6
# 950           8              6
# 951          12              5
# 952          11              5
#
# [953 rows x 24 columns]

# %% [markdown]
# # Summary Statistics

# %%
#Cleaning data types of other columns since other numerical columns are in string (object) data type
dfdesc = df.describe(include='all')
dfdesc
# Out:
#        track_name artist(s)_name  artist_count  released_year  released_month  \
# count         953            953    953.000000     953.000000      953.000000
# unique        943            645           NaN            NaN             NaN
# top      Daylight   Taylor Swift           NaN            NaN             NaN
# freq            2             34           NaN            NaN             NaN
# mean          NaN            NaN      1.556139    2018.238195        6.033578
# std           NaN            NaN      0.893044      11.116218        3.566435
# min           NaN            NaN      1.000000    1930.000000        1.000000
# 25%           NaN            NaN      1.000000    2020.000000        3.000000
# 50%           NaN            NaN      1.000000    2022.000000        6.000000
# 75%           NaN            NaN      2.000000    2022.000000        9.000000
# max           NaN            NaN      8.000000    2023.000000       12.000000
#
#         released_day  in_spotify_playlists  in_spotify_charts       streams  \
# count     953.000000            953.000000         953.000000  9.520000e+02
# unique           NaN                   NaN                NaN           NaN
# top              NaN                   NaN                NaN           NaN
# freq             NaN                   NaN                NaN           NaN
# mean       13.930745           5200.124869          12.009444  5.141374e+08
# std         9.201949           7897.608990          19.575992  5.668569e+08
# min         1.000000             31.000000           0.000000  2.762000e+03
# 25%         6.000000            875.000000           0.000000  1.416362e+08
# 50%        13.000000           2224.000000           3.000000  2.905309e+08
# 75%        22.000000           5542.000000          16.000000  6.738690e+08
# max        31.000000          52898.000000         147.000000  3.703895e+09
#
#         in_apple_playlists  ...         bpm  key   mode  danceability_%  \
# count           953.000000  ...  953.000000  858    953       953.00000
# unique                 NaN  ...         NaN   11      2             NaN
# top                    NaN  ...         NaN   C#  Major             NaN
# freq                   NaN  ...         NaN  120    550             NaN
# mean             67.812172  ...  122.540399  NaN    NaN        66.96957
# std              86.441493  ...   28.057802  NaN    NaN        14.63061
# min               0.000000  ...   65.000000  NaN    NaN        23.00000
# 25%              13.000000  ...  100.000000  NaN    NaN        57.00000
# 50%              34.000000  ...  121.000000  NaN    NaN        69.00000
# 75%              88.000000  ...  140.000000  NaN    NaN        78.00000
# max             672.000000  ...  206.000000  NaN    NaN        96.00000
#
#          valence_%    energy_% acousticness_%  instrumentalness_%  liveness_%  \
# count   953.000000  953.000000     953.000000          953.000000  953.000000
# unique         NaN         NaN            NaN                 NaN         NaN
# top            NaN         NaN            NaN                 NaN         NaN
# freq           NaN         NaN            NaN                 NaN         NaN
# mean     51.431270   64.279119      27.057712            1.581322   18.213012
# std      23.480632   16.550526      25.996077            8.409800   13.711223
# min       4.000000    9.000000       0.000000            0.000000    3.000000
# 25%      32.000000   53.000000       6.000000            0.000000   10.000000
# 50%      51.000000   66.000000      18.000000            0.000000   12.000000
# 75%      70.000000   77.000000      43.000000            0.000000   24.000000
# max      97.000000   97.000000      97.000000           91.000000   97.000000
#
#         speechiness_%
# count      953.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean        10.131165
# std          9.912888
# min          2.000000
# 25%          4.000000
# 50%          6.000000
# 75%         11.000000
# max         64.000000
#
# [11 rows x 24 columns]

# %% [markdown]
# # Overview of Dataset

# %%
#Number of rows and columns of the Dataset. Note that the output of the .shape function is (Rows, Columns)
rows, columns = df.shape
print('Rows: ', rows, '\nColumns: ', columns)
# Out:
# Rows:  953
# Columns:  24

# %%
#Data type of each column. Note that the object data types are in strings
df.dtypes
# Out:
# track_name               object
# artist(s)_name           object
# artist_count              int64
# released_year             int64
# released_month            int64
# released_day              int64
# in_spotify_playlists      int64
# in_spotify_charts         int64
# streams                 float64
# in_apple_playlists        int64
# in_apple_charts           int64
# in_deezer_playlists       int64
# in_deezer_charts          int64
# in_shazam_charts        float64
# bpm                       int64
# key                      object
# mode                     object
# danceability_%            int64
# valence_%                 int64
# energy_%                  int64
# acousticness_%            int64
# instrumentalness_%        int64
# liveness_%                int64
# speechiness_%             int64
# dtype: object

# %%
#Columns with missing values
mcount = df.isnull().sum()
print('COLUMN \t\t MISSING COUNT')
print(mcount[mcount>0])
# Out:
# COLUMN 		 MISSING COUNT
# streams              1
# in_shazam_charts    50
# key                 95
# dtype: int64

# %% [markdown]
# # Basic Descriptive Statistics

# %%
#Mean, Median, and Standard Deviation of streams column
print('Mean: ', round(df['streams'].mean(), 2))
print('Median: ', round(df['streams'].median(), 2))
print('Standard Deviation: ', round(df['streams'].std(), 2))
# Out:
# Mean:  514137424.94
# Median:  290530915.0
# Standard Deviation:  566856949.04

# %%
#Distribution of released_year and artist_count
dfdesc.loc[:,['released_year', 'artist_count']]
# Out:
#         released_year  artist_count
# count      953.000000    953.000000
# unique            NaN           NaN
# top               NaN           NaN
# freq              NaN           NaN
# mean      2018.238195      1.556139
# std         11.116218      0.893044
# min       1930.000000      1.000000
# 25%       2020.000000      1.000000
# 50%       2022.000000      1.000000
# 75%       2022.000000      2.000000
# max       2023.000000      8.000000

# %%
#Distribution of released_year and artist_count
plt.figure(figsize=(24,10))
sns.stripplot(x='artist_count',
            y='released_year',
            data=df)
# Out:
# <Axes: xlabel='artist_count', ylabel='released_year'>

# %% [markdown]
# # Top Performers

# %%
#Top 5 most streamed tracks
toptracks = df.sort_values(by='streams', ascending=False)
top5tracks = toptracks.head(5)[['track_name', 'streams']]

plt.figure(figsize=(17,7))
sns.barplot(x='track_name', y='streams', data=top5tracks)
plt.xlabel('Track Name')
plt.ylabel('Total Streams')
# Out:
# Text(0, 0.5, 'Total Streams')

# %%
#Top 5 most frequent artists based on the number of tracks
splitnames = df['artist(s)_name'].str.split(', ')
srows = splitnames.explode()
freqartist = srows.value_counts().head(5)
dffreqartist = pd.DataFrame(freqartist)

plt.figure(figsize=(17,7))
sns.barplot(x='artist(s)_name', y='count', data=dffreqartist)
plt.xlabel('Artist Name')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Temporal Trends

# %%
#Number of tracks released per year
numtrackyear = df.groupby('released_year')['track_name'].count()
plt.figure(figsize=(24,10))
sns.barplot(data=numtrackyear)
plt.ylabel('Number of Tracks')
# Out:
# Text(0, 0.5, 'Number of Tracks')

# %%
#Number of tracks released per month
numtrackmnth = df.groupby('released_month')['track_name'].count()
plt.figure(figsize=(24,10))
sns.barplot(data=numtrackmnth)
plt.ylabel('Number of Tracks')
# Out:
# Text(0, 0.5, 'Number of Tracks')

# %% [markdown]
# # Genre and Music Characteristics

# %%
#Identifying correlations between streams and musical attributes using a heatmap
corrstma = df[['bpm', 'danceability_%', 'valence_%', 
               'energy_%', 'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']].corrwith(df['streams'])

dfcorrstma = pd.DataFrame(corrstma)

plt.figure(figsize=(7,7))
sns.heatmap(dfcorrstma, annot=True, cmap='Reds')
plt.title('Correlation between streams and musical attributes')
plt.xlabel('Streams')
plt.ylabel('Musical Attributes')
# Out:
# Text(58.08159722222221, 0.5, 'Musical Attributes')

# %%
#Using a scatterplot to analyze correlation between streams and musical attributes
#Correlation between streams and bpm
plt.figure(figsize=(10,10))
sns.scatterplot(x='bpm', y='streams', data=df)
# Out:
# <Axes: xlabel='bpm', ylabel='streams'>

# %%
#Correlation between streams and danceability
plt.figure(figsize=(10,10))
sns.scatterplot(x='danceability_%', y='streams', data=df)
plt.xticks(range(0,101,20))
# Out:
# ([<matplotlib.axis.XTick at 0x206011e8530>,
#   <matplotlib.axis.XTick at 0x206011eb9e0>,
#   <matplotlib.axis.XTick at 0x2067aca6960>,
#   <matplotlib.axis.XTick at 0x206011f7560>,
#   <matplotlib.axis.XTick at 0x206011f7a10>,
#   <matplotlib.axis.XTick at 0x2060122c3e0>],
#  [Text(0, 0, '0'),
#   Text(20, 0, '20'),
#   Text(40, 0, '40'),
#   Text(60, 0, '60'),
#   Text(80, 0, '80'),
#   Text(100, 0, '100')])

# %%
#Correlation between streams and valence
plt.figure(figsize=(10,10))
sns.scatterplot(x='valence_%', y='streams', data=df)
plt.xticks(range(0,101,20))
# Out:
# ([<matplotlib.axis.XTick at 0x20601254080>,
#   <matplotlib.axis.XTick at 0x206012557f0>,
#   <matplotlib.axis.XTick at 0x206006b3fb0>,
#   <matplotlib.axis.XTick at 0x20600f9a240>,
#   <matplotlib.axis.XTick at 0x20600f9a2d0>,
#   <matplotlib.axis.XTick at 0x20600f9b050>],
#  [Text(0, 0, '0'),
#   Text(20, 0, '20'),
#   Text(40, 0, '40'),
#   Text(60, 0, '60'),
#   Text(80, 0, '80'),
#   Text(100, 0, '100')])

# %%
#Correlation between streams and energy
plt.figure(figsize=(10,10))
sns.scatterplot(x='energy_%', y='streams', data=df)
plt.xticks(range(0,101,20))
# Out:
# ([<matplotlib.axis.XTick at 0x20600fb5eb0>,
#   <matplotlib.axis.XTick at 0x20661d7a1e0>,
#   <matplotlib.axis.XTick at 0x20670a34e00>,
#   <matplotlib.axis.XTick at 0x20600fd33b0>,
#   <matplotlib.axis.XTick at 0x20601005b50>,
#   <matplotlib.axis.XTick at 0x20601006210>],
#  [Text(0, 0, '0'),
#   Text(20, 0, '20'),
#   Text(40, 0, '40'),
#   Text(60, 0, '60'),
#   Text(80, 0, '80'),
#   Text(100, 0, '100')])

# %%
#Correlation between streams and acousticness
plt.figure(figsize=(10,10))
sns.scatterplot(x='acousticness_%', y='streams', data=df)
plt.xticks(range(0,101,20))
# Out:
# ([<matplotlib.axis.XTick at 0x20601038da0>,
#   <matplotlib.axis.XTick at 0x2066252a1e0>,
#   <matplotlib.axis.XTick at 0x20675b7c950>,
#   <matplotlib.axis.XTick at 0x20601027620>,
#   <matplotlib.axis.XTick at 0x2060106da00>,
#   <matplotlib.axis.XTick at 0x2060106df70>],
#  [Text(0, 0, '0'),
#   Text(20, 0, '20'),
#   Text(40, 0, '40'),
#   Text(60, 0, '60'),
#   Text(80, 0, '80'),
#   Text(100, 0, '100')])

# %%
#Correlation between streams and instrumentalness
plt.figure(figsize=(10,10))
sns.scatterplot(x='instrumentalness_%', y='streams', data=df)
plt.xticks(range(0,101,20))
# Out:
# ([<matplotlib.axis.XTick at 0x2060103ad50>,
#   <matplotlib.axis.XTick at 0x20601027440>,
#   <matplotlib.axis.XTick at 0x20601027ce0>,
#   <matplotlib.axis.XTick at 0x2067cee2db0>,
#   <matplotlib.axis.XTick at 0x206016ec590>,
#   <matplotlib.axis.XTick at 0x206016ed4f0>],
#  [Text(0, 0, '0'),
#   Text(20, 0, '20'),
#   Text(40, 0, '40'),
#   Text(60, 0, '60'),
#   Text(80, 0, '80'),
#   Text(100, 0, '100')])

# %%
#Correlation between streams and liveness
plt.figure(figsize=(10,10))
sns.scatterplot(x='liveness_%', y='streams', data=df)
plt.xticks(range(0,101,20))
# Out:
# ([<matplotlib.axis.XTick at 0x2060170aa80>,
#   <matplotlib.axis.XTick at 0x2060170a1e0>,
#   <matplotlib.axis.XTick at 0x20600f6dd30>,
#   <matplotlib.axis.XTick at 0x20601026a50>,
#   <matplotlib.axis.XTick at 0x20601750650>,
#   <matplotlib.axis.XTick at 0x20601750d70>],
#  [Text(0, 0, '0'),
#   Text(20, 0, '20'),
#   Text(40, 0, '40'),
#   Text(60, 0, '60'),
#   Text(80, 0, '80'),
#   Text(100, 0, '100')])

# %%
#Correlation between streams and speechiness
plt.figure(figsize=(10,10))
sns.scatterplot(x='speechiness_%', y='streams', data=df)
plt.xticks(range(0,101,20))
# Out:
# ([<matplotlib.axis.XTick at 0x206017739e0>,
#   <matplotlib.axis.XTick at 0x206017721e0>,
#   <matplotlib.axis.XTick at 0x206010271a0>,
#   <matplotlib.axis.XTick at 0x20601726ff0>,
#   <matplotlib.axis.XTick at 0x206017878c0>,
#   <matplotlib.axis.XTick at 0x20601787fe0>],
#  [Text(0, 0, '0'),
#   Text(20, 0, '20'),
#   Text(40, 0, '40'),
#   Text(60, 0, '60'),
#   Text(80, 0, '80'),
#   Text(100, 0, '100')])

# %%
#Correlation between danceability and energy
plt.figure(figsize=(10,10))
sns.scatterplot(x='danceability_%', y='energy_%', data=df)
plt.xticks(range(0,101,20))
# Out:
# ([<matplotlib.axis.XTick at 0x2060235e240>,
#   <matplotlib.axis.XTick at 0x2060235ef00>,
#   <matplotlib.axis.XTick at 0x2060235d8b0>,
#   <matplotlib.axis.XTick at 0x206023a84d0>,
#   <matplotlib.axis.XTick at 0x206006b26c0>,
#   <matplotlib.axis.XTick at 0x2060235dfd0>],
#  [Text(0, 0, '0'),
#   Text(20, 0, '20'),
#   Text(40, 0, '40'),
#   Text(60, 0, '60'),
#   Text(80, 0, '80'),
#   Text(100, 0, '100')])

# %%
#Correlation between valence and acousticness
plt.figure(figsize=(10,10))
sns.scatterplot(x='acousticness_%', y='valence_%', data=df)
plt.xticks(range(0,101,20))
# Out:
# ([<matplotlib.axis.XTick at 0x206023ca030>,
#   <matplotlib.axis.XTick at 0x20662cba1e0>,
#   <matplotlib.axis.XTick at 0x206023ca8a0>,
#   <matplotlib.axis.XTick at 0x206023cb110>,
#   <matplotlib.axis.XTick at 0x206023ef260>,
#   <matplotlib.axis.XTick at 0x206023ef9e0>],
#  [Text(0, 0, '0'),
#   Text(20, 0, '20'),
#   Text(40, 0, '40'),
#   Text(60, 0, '60'),
#   Text(80, 0, '80'),
#   Text(100, 0, '100')])

# %% [markdown]
# # Platform Popularity

# %%
#Comparing number of tracks in spotify_playlists, apple_playlists, and deezer_playlists
ntracks = pd.DataFrame({'Platform': ['Spotify', 'Apple', 'Deezer'],
                       'Total # of Tracks': [df['in_spotify_playlists'].sum(), df['in_apple_playlists'].sum(), 
                                                df['in_deezer_playlists'].sum()]})
print(ntracks)
sns.barplot(x='Platform', y='Total # of Tracks', data=ntracks)
# Out:
#   Platform  Total # of Tracks
# 0  Spotify            4955719
# 1    Apple              64625
# 2   Deezer             367084
# <Axes: xlabel='Platform', ylabel='Total # of Tracks'>

# %% [markdown]
# # Advanced Analysis

# %%
#Based on the streams data, patterns among tracks with the same key
skey = df.groupby('key')['streams'].sum()
dfskey = pd.DataFrame(skey)
plt.figure(figsize=(12,7))
sns.barplot(x='key', y='streams', data=dfskey)

#Based on the streams data, patterns among tracks with the same mode (Major vs. Minor)?
smode = df.groupby('mode')['streams'].sum()
dfsmode = pd.DataFrame(smode)
plt.figure(figsize=(7,7))
sns.barplot(x='mode', y='streams', data=dfsmode)
# Out:
# <Axes: xlabel='mode', ylabel='streams'>

# %%
#Most frequently appearing artists in playlists or charts
df1 = df
df1['artist(s)_name'] = splitnames

spotifypl = df1.explode('artist(s)_name').groupby('artist(s)_name')['in_spotify_playlists'].sum().sort_values(ascending=False).head(5)

applepl = df1.explode('artist(s)_name').groupby('artist(s)_name')['in_apple_playlists'].sum().sort_values(ascending=False).head(5)

deezerpl = df1.explode('artist(s)_name').groupby('artist(s)_name')['in_deezer_playlists'].sum().sort_values(ascending=False).head(5)

spotifych = df1.explode('artist(s)_name').groupby('artist(s)_name')['in_spotify_charts'].sum().sort_values(ascending=False).head(5)

applech = df1.explode('artist(s)_name').groupby('artist(s)_name')['in_apple_charts'].sum().sort_values(ascending=False).head(5)

deezerch = df1.explode('artist(s)_name').groupby('artist(s)_name')['in_deezer_charts'].sum().sort_values(ascending=False).head(5)

shazamch = df1.explode('artist(s)_name').groupby('artist(s)_name')['in_shazam_charts'].sum().sort_values(ascending=False).head(5)

#Most frequent artists based on number of spotify playlist
plt.figure(figsize=(7,7))
sns.barplot(data=spotifypl)

#Most frequent artists based on number of apple playlist
plt.figure(figsize=(7,7))
sns.barplot(data=applepl)

#Most frequent artists based on number of deezer playlist
plt.figure(figsize=(7,7))
sns.barplot(data=deezerpl)

#Most frequent artists based on number of spotify charts
plt.figure(figsize=(7,7))
sns.barplot(data=spotifych)

#Most frequent artists based on number of apple charts
plt.figure(figsize=(7,7))
sns.barplot(data=applech)

#Most frequent artists based on number of deezer charts
plt.figure(figsize=(7,7))
sns.barplot(data=deezerch)

##Most frequent artists based on number of shazam charts
plt.figure(figsize=(7,7))
sns.barplot(data=shazamch)
# Out:
# <Axes: xlabel='artist(s)_name', ylabel='in_shazam_charts'>
